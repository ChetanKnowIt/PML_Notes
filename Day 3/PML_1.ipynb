# %% [markdown]
# # Logistic Regression
# * its a classification method
# * uses log loss
# * gives us odds of an event
# * b value coef are found using maximum likelihood method
# * y prob are between 0 and 1

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from google.colab import drive
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, r2_score, f1_score, accuracy_score, classification_report
from sklearn.metrics import roc_auc_score, log_loss
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, accuracy_score


hr_path = '/content/gdrive/MyDrive/Datasets/human-resources-analytics/HR_comma_sep.csv'
hr = pd.read_csv(hr_path)

# 1st get dummies
dum_hr = pd.get_dummies(hr, drop_first=True)

# get X & y
X = dum_hr.drop('left', axis = 1)
y = dum_hr['left']

X_train, X_test, y_train, y_test = train_test_split(X, y,stratify = y,random_state=2022,train_size=0.7)

# apply regression 
lr = LogisticRegression()
lr.fit(X_train, y_train)
y_pred = lr.predict(X_test)
y_pred_prob = lr.predict_proba(X_test)[:,1]
print(accuracy_score(y_test, y_pred))
print(roc_auc_score(y_test, y_pred_prob))


# take grid search cv
from sklearn.model_selection import GridSearchCV, StratifiedKFold
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 2022)
lr = LogisticRegression(solver = 'saga', random_state = 2022)
params = {'penalty': ['l1','l2','elasticnet', None],
          'C':np.linspace(0.001, 4, 5),
          'l1_ratio':np.linspace(0.001, 1, 5)}
gcv = GridSearchCV(lr, param_grid= params, scoring = 'roc_auc', cv = kfold, verbose =3)
gcv.fit(X, y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# 0.7857777777777778
# 0.812740183076244
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
# ...

# %%
scaler = StandardScaler()
lr = LogisticRegression()

pipe = Pipeline([('STD', scaler), ('LR', lr)])
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 2022)
params = {'LR__penalty': ['l1','l2','elasticnet', None],
          'LR__C':np.linspace(0.001, 4, 5),
          'LR__l1_ratio':np.linspace(0.001, 1, 5)}
gcv = GridSearchCV(pipe, param_grid = params, scoring = 'roc_auc', cv=kfold, verbose = 3)
gcv.fit(X,y)
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=nan total time=   0.0s
# [CV 2/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=nan total time=   0.0s
# [CV 3/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=nan total time=   0.0s
# [CV 4/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=nan total time=   0.0s
# [CV 5/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=nan total time=   0.0s
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l2)
#   warnings.warn(
# ...

# %% [markdown]
# # Bankruptcy
# 1. D is the y
# 2. r1, r2, ... r24 are X
#
# * ### Conclusions:
# * without saga and random_state:
#
#   {'LR__C': 0.001, 'LR__l1_ratio': 0.001, 'LR__penalty': 'l2'}
#
#   best  roc_auc score: 0.8772612003381235
#
# * with saga and random_state:
#
#   {'LR__C': 0.001, 'LR__l1_ratio': 0.001, 'LR__penalty': 'elasticnet'}
#
#   best  roc_auc score: 0.881825866441251

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from google.colab import drive
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression


import warnings
warnings.filterwarnings(action='once')


bank_path = '/content/gdrive/MyDrive/Datasets/Bankruptcy/Bankruptcy.csv'
Bankruptcy = pd.read_csv(bank_path)
X = Bankruptcy.drop(['NO','YR','D'], axis=1)
y = Bankruptcy['D']


scaler = StandardScaler()
lr = LogisticRegression(solver = 'saga', random_state = 2022)

pipe = Pipeline([('STD', scaler), ('LR', lr)])
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 2022)
params = {'LR__penalty': ['l1','l2','elasticnet', None],
          'LR__C':np.linspace(0.001, 4, 5),
          'LR__l1_ratio':np.linspace(0.001, 1, 5)}
gcv = GridSearchCV(pipe, param_grid = params, scoring = 'roc_auc', cv=kfold, verbose = 3)
gcv.fit(X,y)

# without saga and random_state: 
# {'LR__C': 0.001, 'LR__l1_ratio': 0.001, 'LR__penalty': 'l2'}
# 0.8772612003381235

# with saga and random_state:
# {'LR__C': 0.001, 'LR__l1_ratio': 0.001, 'LR__penalty': 'elasticnet'}
# 0.881825866441251
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=0.500 total time=   0.0s
# [CV 2/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=0.500 total time=   0.0s
# [CV 3/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=0.500 total time=   0.0s
# [CV 4/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=0.500 total time=   0.0s
# [CV 5/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l1;, score=0.500 total time=   0.0s
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l2;, score=0.813 total time=   0.0s
# [CV 2/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l2;, score=0.780 total time=   0.0s
# [CV 3/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l2;, score=0.858 total time=   0.0s
# [CV 4/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__penalty=l2;, score=0.953 total time=   0.0s
# ...

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'LR__C': 0.001, 'LR__l1_ratio': 0.001, 'LR__penalty': 'elasticnet'}
# 0.881825866441251

# %% [markdown]
# # Image Segmentation with ovr/multinomial

# %%
# we will try another parameter inside logistic regression 
# ovr and multinomial 
from sklearn.preprocessing import LabelEncoder
img_path = '/content/gdrive/MyDrive/Datasets/Image Segmentation/Image_Segmention.csv'
img_seg = pd.read_csv(img_path)

X = img_seg.drop('Class',axis=1)
y = img_seg['Class']

le = LabelEncoder()
le_y = le.fit_transform(y)

scaler = StandardScaler()
lr = LogisticRegression(solver = 'saga', random_state = 2022, max_iter=1000)

pipe = Pipeline([('STD', scaler), ('LR', lr)])
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 2022)
params = {'LR__penalty': ['l1','l2','elasticnet', None],
          'LR__C':np.linspace(0.001, 4, 5),
          'LR__l1_ratio':np.linspace(0.001, 1, 5),
          'LR__multi_class':['ovr', 'multinomial']}
gcv = GridSearchCV(pipe, param_grid = params, scoring = 'neg_log_loss', cv=kfold, verbose = 3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.946 total time=   0.0s
# [CV 2/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.946 total time=   0.0s
# [CV 3/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.946 total time=   0.0s
# [CV 4/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.946 total time=   0.0s
# [CV 5/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.945 total time=   0.0s
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l2;, score=-1.784 total time=   0.1s
# /usr/local/lib/python3.8/dist-packages/sklearn/linear_model/_logistic.py:1476: UserWarning: l1_ratio parameter is only used when penalty is 'elasticnet'. Got (penalty=l1)
#   warnings.warn(
# ...

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'LR__C': 2.0005, 'LR__l1_ratio': 0.001, 'LR__multi_class': 'multinomial', 'LR__penalty': 'l1'}
# -0.2909145607518697

# %% [markdown]
# # Vehicle Silhouette Dataset
#
# 1. y = Class
# 2.

# %%
# another example for ovr and multinomial 
from sklearn.preprocessing import LabelEncoder
vehi_path = '/content/gdrive/MyDrive/Datasets/Vehicle Silhouettes/Vehicle.csv'
veh_sil = pd.read_csv(vehi_path)

X = veh_sil.drop('Class',axis=1)
y = veh_sil['Class']

le = LabelEncoder()
le_y = le.fit_transform(y)

scaler = StandardScaler()
lr = LogisticRegression(solver = 'saga', random_state = 2022, max_iter=1000)

pipe = Pipeline([('STD', scaler), ('LR', lr)])
kfold = StratifiedKFold(n_splits = 5, shuffle = True, random_state = 2022)
params = {'LR__penalty': ['l1','l2','elasticnet', None],
          'LR__C':np.linspace(0.001, 4, 5),
          'LR__l1_ratio':np.linspace(0.001, 1, 5),
          'LR__multi_class':['ovr', 'multinomial']}
gcv = GridSearchCV(pipe, param_grid = params, scoring = 'neg_log_loss', cv=kfold, verbose = 3)
gcv.fit(X,y)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.386 total time=   0.0s
# [CV 2/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.386 total time=   0.0s
# [CV 3/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.386 total time=   0.0s
# [CV 4/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.386 total time=   0.0s
# [CV 5/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l1;, score=-1.387 total time=   0.0s
# [CV 1/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l2;, score=-1.249 total time=   0.0s
# [CV 2/5] END LR__C=0.001, LR__l1_ratio=0.001, LR__multi_class=ovr, LR__penalty=l2;, score=-1.263 total time=   0.0s
# ...

# %%
print(gcv.best_params_)
print(gcv.best_score_)
# Out:
# {'LR__C': 4.0, 'LR__l1_ratio': 0.001, 'LR__multi_class': 'multinomial', 'LR__penalty': 'l1'}
# -0.4057203481816787

# %% [markdown]
# # Baye's Theorem on Telecom
# 1. we will apply it for Telecom dataset
# 2. we will try to find bought/not bought with y = Response

# %%
from sklearn.naive_bayes import BernoulliNB
from sklearn.metrics import roc_auc_score, accuracy_score
from sklearn.model_selection import train_test_split
import pandas as pd

tel_path = '/content/gdrive/MyDrive/Datasets/Telecom/Telecom.csv'
tele = pd.read_csv(tel_path)

# 1st get dummies
dum_tel = pd.get_dummies(tele, drop_first=True)
dum_tel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Gender_M     150 non-null    uint8
#  1   TT_gt_100_Y  150 non-null    uint8
#  2   Response_Y   150 non-null    uint8
# dtypes: uint8(3)
# memory usage: 578.0 bytes

# %%
# get X & y
X = dum_tel.drop('Response_Y', axis = 1)
y = dum_tel['Response_Y']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state=2022, train_size=0.7)

# apply regression 
nb = BernoulliNB()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)[:,1]
print(accuracy_score(y_test, y_pred))
print(roc_auc_score(y_test, y_pred_prob))
# Out:
# 0.9555555555555556
# 0.9407114624505929

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
kfold = StratifiedKFold(n_splits=5, 
                        shuffle=True,random_state=2022)
nb = BernoulliNB()
result = cross_val_score(nb, 
                         X,y, 
                         cv=kfold, 
                         scoring='roc_auc')
print(result.mean())
# Out:
# 0.8835753968253968

# %%
can_path = '/content/gdrive/MyDrive/Datasets/Cancer/Cancer.csv'
cancer = pd.read_csv(can_path)
cancer.drop('subjid', inplace=True, axis =1)

# 1st get dummies
can_dum = pd.get_dummies(cancer, drop_first=True)
can_dum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 286 entries, 0 to 285
# Data columns (total 32 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   deg-malig                286 non-null    int64
#  1   age_30-39                286 non-null    uint8
#  2   age_40-49                286 non-null    uint8
#  3   age_50-59                286 non-null    uint8
#  4   age_60-69                286 non-null    uint8
#  5   age_70-79                286 non-null    uint8
#  6   menopause_lt40           286 non-null    uint8
#  7   menopause_premeno        286 non-null    uint8
#  8   tumor-size_10-14         286 non-null    uint8
#  9   tumor-size_15-19         286 non-null    uint8
#  10  tumor-size_20-24         286 non-null    uint8
#  11  tumor-size_25-29         286 non-null    uint8
#  12  tumor-size_30-34         286 non-null    uint8
#  13  tumor-size_35-39         286 non-null    uint8
# ...

# %%
# get X & y
X = can_dum.drop('Class_recurrence-events', axis = 1)
y = can_dum['Class_recurrence-events']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, random_state=2022, train_size=0.7)

# apply regression 
nb = BernoulliNB()
nb.fit(X_train, y_train)
y_pred = nb.predict(X_test)
y_pred_prob = nb.predict_proba(X_test)[:,1]
print(accuracy_score(y_test, y_pred))
print(roc_auc_score(y_test, y_pred_prob))
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
kfold = StratifiedKFold(n_splits=5, 
                        shuffle=True,random_state=2022)
nb = BernoulliNB()
result = cross_val_score(nb, 
                         X,y, 
                         cv=kfold, 
                         scoring='roc_auc')
print(result.mean())
# Out:
# 0.813953488372093
# 0.8006410256410256
# 0.6690208034433285
